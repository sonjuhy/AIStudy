# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join("..")))
print(os.path.abspath(os.path.join("..")))
# Out:
# /media/edint/64d115f7-57cc-417b-acf0-7738ac091615/Ivern/WorkSpace/CNN

# %%
from dataset import download_dataset

loader_dict = download_dataset()
train_loader = loader_dict["train"]
test_loader = loader_dict["test"]


# CIFAR-10 클래스 이름
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# 테스트셋에서 일부 샘플 가져오기
dataiter = iter(test_loader)
images, labels = next(dataiter)

# %%
from mobilenet.mobilenet_3 import MobileNetV3Large

import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device : {device}")
model = MobileNetV3Large(num_classes=10).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Device : cuda
# /home/edint/Ivern/WorkSpace/CNN/venv/lib/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
print('Start Training...')
epochs = 30

train_losses, val_losses = [], []
train_accs, val_accs = [], []

for epoch in range(epochs):
    # ---- Training ----
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    print(
        f"[Epoch {epoch+1}] Train Loss: {running_loss/len(train_loader):.4f} | Train Acc: {train_acc:.2f}%"
    )

    # ---- Validation ----
    model.eval()
    correct, total = 0, 0
    val_loss_sum = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            val_loss_sum  += criterion(outputs, labels).item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    val_loss = val_loss_sum / len(test_loader)
    val_acc = 100. * correct / total
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    print(
        f"           Val Loss: {val_loss/len(test_loader):.4f} | Val Acc: {val_acc:.2f}%\n"
    )
    torch.save(model.state_dict(), "mobilenetv3_large_cifar10.pth")
# Out:
# Start Training...
# [Epoch 1] Train Loss: 1.3335 | Train Acc: 50.84%
#            Val Loss: 0.0064 | Val Acc: 63.88%
#
# [Epoch 2] Train Loss: 0.8600 | Train Acc: 69.59%
#            Val Loss: 0.0048 | Val Acc: 74.69%
#
# [Epoch 3] Train Loss: 0.6572 | Train Acc: 76.88%
#            Val Loss: 0.0039 | Val Acc: 79.21%
#
# [Epoch 4] Train Loss: 0.5400 | Train Acc: 81.50%
#            Val Loss: 0.0034 | Val Acc: 82.29%
#
# [Epoch 5] Train Loss: 0.4714 | Train Acc: 83.80%
#            Val Loss: 0.0034 | Val Acc: 82.59%
#
# [Epoch 6] Train Loss: 0.4105 | Train Acc: 85.79%
#            Val Loss: 0.0030 | Val Acc: 84.16%
#
# [Epoch 7] Train Loss: 0.3708 | Train Acc: 87.14%
#            Val Loss: 0.0028 | Val Acc: 84.60%
#
# [Epoch 8] Train Loss: 0.3301 | Train Acc: 88.54%
#            Val Loss: 0.0027 | Val Acc: 85.93%
#
# [Epoch 9] Train Loss: 0.2964 | Train Acc: 89.81%
#            Val Loss: 0.0027 | Val Acc: 86.58%
#
# [Epoch 10] Train Loss: 0.2642 | Train Acc: 90.91%
#            Val Loss: 0.0028 | Val Acc: 86.63%
#
# [Epoch 11] Train Loss: 0.2457 | Train Acc: 91.53%
#            Val Loss: 0.0027 | Val Acc: 86.56%
#
# [Epoch 12] Train Loss: 0.2160 | Train Acc: 92.45%
#            Val Loss: 0.0024 | Val Acc: 87.82%
#
# [Epoch 13] Train Loss: 0.2000 | Train Acc: 93.07%
#            Val Loss: 0.0025 | Val Acc: 87.54%
#
# [Epoch 14] Train Loss: 0.1844 | Train Acc: 93.61%
#            Val Loss: 0.0026 | Val Acc: 87.95%
#
# [Epoch 15] Train Loss: 0.1715 | Train Acc: 94.02%
#            Val Loss: 0.0024 | Val Acc: 88.52%
#
# [Epoch 16] Train Loss: 0.1535 | Train Acc: 94.66%
#            Val Loss: 0.0023 | Val Acc: 88.75%
#
# [Epoch 17] Train Loss: 0.1407 | Train Acc: 95.04%
#            Val Loss: 0.0029 | Val Acc: 87.70%
#
# [Epoch 18] Train Loss: 0.1307 | Train Acc: 95.36%
#            Val Loss: 0.0025 | Val Acc: 88.77%
#
# [Epoch 19] Train Loss: 0.1238 | Train Acc: 95.68%
#            Val Loss: 0.0026 | Val Acc: 88.98%
#
# [Epoch 20] Train Loss: 0.1142 | Train Acc: 96.08%
#            Val Loss: 0.0026 | Val Acc: 89.06%
#
# [Epoch 21] Train Loss: 0.1065 | Train Acc: 96.26%
#            Val Loss: 0.0026 | Val Acc: 88.67%
#
# [Epoch 22] Train Loss: 0.1008 | Train Acc: 96.52%
#            Val Loss: 0.0026 | Val Acc: 89.02%
#
# [Epoch 23] Train Loss: 0.0933 | Train Acc: 96.84%
#            Val Loss: 0.0028 | Val Acc: 88.45%
#
# [Epoch 24] Train Loss: 0.0901 | Train Acc: 96.94%
#            Val Loss: 0.0027 | Val Acc: 88.77%
#
# [Epoch 25] Train Loss: 0.0871 | Train Acc: 96.95%
#            Val Loss: 0.0027 | Val Acc: 89.41%
#
# [Epoch 26] Train Loss: 0.0777 | Train Acc: 97.30%
#            Val Loss: 0.0028 | Val Acc: 88.78%
#
# [Epoch 27] Train Loss: 0.0778 | Train Acc: 97.33%
#            Val Loss: 0.0030 | Val Acc: 88.70%
#
# [Epoch 28] Train Loss: 0.0756 | Train Acc: 97.36%
#            Val Loss: 0.0029 | Val Acc: 89.22%
#
# [Epoch 29] Train Loss: 0.0677 | Train Acc: 97.61%
#            Val Loss: 0.0028 | Val Acc: 89.75%
#
# [Epoch 30] Train Loss: 0.0705 | Train Acc: 97.54%
#            Val Loss: 0.0028 | Val Acc: 89.28%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, 'o-', label='Train Loss')
plt.plot(range(1, epochs+1), val_losses, 's--', label='Val Loss')
plt.title('Loss Trend')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accs, 'o-', label='Train Accuracy')
plt.plot(range(1, epochs+1), val_accs, 's--', label='Val Accuracy')
plt.title('Accuracy Trend')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()
